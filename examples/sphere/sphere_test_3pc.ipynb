# %%
from traj2sim import *
import math
from mpl_toolkits import mplot3d
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
        
def plot_2pc_traj(list_traj):
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    for i in range(len(list_traj)):
        xdata = list_traj[i][:,1]
        ydata = list_traj[i][:,2]
        zdata = list_traj[i][:,3]
        if i%2 == 0:
            ax.scatter3D(xdata, ydata, zdata, c='g')
        else:
            ax.scatter3D(xdata, ydata, zdata, c='r')
    plt.show()
    
def plot_3pc_traj(list_traj):
    N = len(list_traj)/3
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    for i in range(len(list_traj)):
        xdata = list_traj[i][:,0]
        ydata = list_traj[i][:,1]
        zdata = list_traj[i][:,2]
        if i < 2*N:
            if i%2 == 0:
                ax.scatter3D(xdata, ydata, zdata, c='g')
            else:
                ax.scatter3D(xdata, ydata, zdata, c='r')
        else:
            ax.scatter3D(xdata, ydata, zdata, c='b')
    plt.show()
        
def sphere_point(theta, phi):
    return [math.sin(phi)*math.cos(theta), math.sin(phi)*math.sin(theta), -math.cos(phi)]

# %%
def great_circle_with_time(theta, length=10, noise=False, sigma=0.05, time_i=0, time_f=10):
    traj = np.zeros((time_f-time_i,4))
    for i in range(0, time_f-time_i):
        traj[i][1:] = sphere_point(theta, (time_i+i)*math.pi/length)
        traj[i][0] = -np.arccos(sphere_point(theta, (time_i+i)*math.pi/length)[2])
        #traj[i][0] = sphere_point(theta, (time_i+i)*math.pi/length)[2]
        if noise == True:
            traj[i][1:] = np.add(traj[i][1:],sigma*np.random.randn(1,3))
    return traj

def great_circle(theta, length=10, noise=False, sigma=0.005, time_i=0, time_f=10):
    traj = np.zeros((time_f-time_i,3))
    for i in range(0, time_f-time_i):
        traj[i] = sphere_point(theta, (time_i+i)*math.pi/length)
        #traj[i][0] = -np.arccos(sphere_point(theta, (time_i+i)*math.pi/length)[2])
        #traj[i][0] = sphere_point(theta, (time_i+i)*math.pi/length)[2]
        if noise == True:
            traj[i] = np.add(traj[i][1:],sigma*np.random.randn(1,3))
    return traj

# %%
t2s = Traj2Sim()
list_traj = []

a=0.7
b=0.4

N=10
length=30

for i in range(2*N):
    if i%2 == 0:
        list_traj.append(great_circle_with_time(2*i*math.pi/(2*N), length, noise=1,time_i=int(0*length), time_f=int(a*length)))
    else:
        list_traj.append(great_circle_with_time(2*i*math.pi/(2*N), length, noise=1,time_i=int((1-a)*length), time_f=int(1*length)-1))    
#for i in range(N):
#    list_traj.append(great_circle_with_time(2*i*math.pi/N, length, noise=1,time_i=int(b*length), time_f=int((1-b)*length)))
        
plot_2pc_traj(list_traj)

t2s.set_trajectories(list_traj)
t2s.dist = 'integral'
t2s.compute_dist(verbose=True)
t2s.compute_sim(verbose=False)


print('Persistence intervals:')
pers = t2s.simplex_tree.persistence(homology_coeff_field=2, min_persistence=-0.1)
pers.sort(key=lambda x: x[1][0]-x[1][1])
print(pers[:10])

gudhi.plot_persistence_diagram(pers[:20])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Custom distance between 0, 0: 0.6752981293703277
# Custom distance between 0, 1: 0.9467362686872159
# Custom distance between 0, 2: 0.8334129951354852
# Custom distance between 0, 3: 1.2202119551879886
# Custom distance between 0, 4: 1.0873012355622804
# Custom distance between 0, 5: 1.4752375597634562
# Custom distance between 0, 6: 1.3033506088807874
# Custom distance between 0, 7: 1.6852168394579485
# Custom distance between 0, 8: 1.4856083052199736
# Custom distance between 0, 9: 1.825522199531206
# Custom distance between 0, 10: 1.5401992168959766
# Custom distance between 0, 11: 1.8131218542000922
# Custom distance between 0, 12: 1.4683672838358584
# Custom distance between 0, 13: 1.6886778623781349
# Custom distance between 0, 14: 1.3220902829990362
# Custom distance between 0, 15: 1.4926356643368963
# Custom distance between 0, 16: 1.0977545782365594
# Custom distance between 0, 17: 1.231919900383457
# Custom distance between 0, 18: 0.845691937030838
# Custom distance between 0, 19: 0.9807470362602051
# Custom distance between 1, 0: 0.9467362686872162
# Custom distance between 1, 1: 0.6146141356661585
# Custom distance between 1, 2: 0.9565168996724411
# Custom distance between 1, 3: 0.8645896060298764
# Custom distance between 1, 4: 1.2131632073015535
# Custom distance between 1, 5: 1.1903441365379754
# Custom distance between 1, 6: 1.4573772590578726
# Custom distance between 1, 7: 1.4837972521429101
# Custom distance between 1, 8: 1.6846344334051142
# Custom distance between 1, 9: 1.6956602280845885
# Custom distance between 1, 10: 1.7943323807907077
# Custom distance between 1, 11: 1.749625361097723
# Custom distance between 1, 12: 1.775486666638812
# Custom distance between 1, 13: 1.66574080059879
# Custom distance between 1, 14: 1.6660320254974335
# Custom distance between 1, 15: 1.4809714870824375
# Custom distance between 1, 16: 1.4573211515769742
# Custom distance between 1, 17: 1.1819412770795354
# Custom distance between 1, 18: 1.19957857237931
# Custom distance between 1, 19: 0.8409952071527129
# Custom distance between 2, 0: 0.8334129951354852
# Custom distance between 2, 1: 0.9565168996724406
# Custom distance between 2, 2: 0.6656779621410003
# Custom distance between 2, 3: 0.9819308311265624
# Custom distance between 2, 4: 0.8355350553441429
# Custom distance between 2, 5: 1.2211019306411313
# Custom distance between 2, 6: 1.0799026508530452
# Custom distance between 2, 7: 1.4879990034176738
# Custom distance between 2, 8: 1.3465252197819844
# Custom distance between 2, 9: 1.722275216876997
# Custom distance between 2, 10: 1.497451410726494
# Custom distance between 2, 11: 1.8230327644861042
# Custom distance between 2, 12: 1.5362625032232928
# Custom distance between 2, 13: 1.8115800307304935
# Custom distance between 2, 14: 1.4880040192731265
# Custom distance between 2, 15: 1.710424157489951
# Custom distance between 2, 16: 1.3289759928368006
# Custom distance between 2, 17: 1.498303721145433
# Custom distance between 2, 18: 1.1031928819796082
# Custom distance between 2, 19: 1.2205130537401694
# Custom distance between 3, 0: 1.2202119551879886
# Custom distance between 3, 1: 0.8645896060298768
# Custom distance between 3, 2: 0.981930831126562
# Custom distance between 3, 3: 0.6406662659038271
# Custom distance between 3, 4: 0.9816223598746778
# Custom distance between 3, 5: 0.8544652343329788
# Custom distance between 3, 6: 1.2012143808329951
# Custom distance between 3, 7: 1.1862545874461512
# Custom distance between 3, 8: 1.489306330618076
# Custom distance between 3, 9: 1.4997877840106266
# Custom distance between 3, 10: 1.6970237208967285
# Custom distance between 3, 11: 1.6936490612592356
# Custom distance between 3, 12: 1.8028572266294534
# Custom distance between 3, 13: 1.759306246322714
# Custom distance between 3, 14: 1.8142641671233488
# Custom distance between 3, 15: 1.7140403427134487
# Custom distance between 3, 16: 1.6990322350252316
# Custom distance between 3, 17: 1.5159960823699463
# Custom distance between 3, 18: 1.5027786617208811
# Custom distance between 3, 19: 1.2088154230125672
# Custom distance between 4, 0: 1.0873012355622809
# Custom distance between 4, 1: 1.2131632073015548
# Custom distance between 4, 2: 0.8355350553441425
# Custom distance between 4, 3: 0.9816223598746783
# Custom distance between 4, 4: 0.6548429893186728
# Custom distance between 4, 5: 0.9723206290801911
# Custom distance between 4, 6: 0.8085392164992857
# Custom distance between 4, 7: 1.2125360639077647
# Custom distance between 4, 8: 1.100805316621969
# Custom distance between 4, 9: 1.497343209497232
# Custom distance between 4, 10: 1.3197244712723273
# Custom distance between 4, 11: 1.6937488890363304
# Custom distance between 4, 12: 1.4662130359782253
# Custom distance between 4, 13: 1.8010357115798783
# Custom distance between 4, 14: 1.5297272843815373
# Custom distance between 4, 15: 1.8213809999578958
# Custom distance between 4, 16: 1.4699967264247202
# Custom distance between 4, 17: 1.7107328592808393
# Custom distance between 4, 18: 1.329391277196909
# Custom distance between 4, 19: 1.491520057761388
# Custom distance between 5, 0: 1.475237559763457
# Custom distance between 5, 1: 1.1903441365379759
# Custom distance between 5, 2: 1.2211019306411333
# Custom distance between 5, 3: 0.8544652343329795
# Custom distance between 5, 4: 0.9723206290801911
# Custom distance between 5, 5: 0.6428373352458469
# Custom distance between 5, 6: 0.9619373563340455
# Custom distance between 5, 7: 0.8533352030770261
# Custom distance between 5, 8: 1.218577134815853
# Custom distance between 5, 9: 1.1934072466027374
# Custom distance between 5, 10: 1.4746917852349153
# Custom distance between 5, 11: 1.4809100978137648
# Custom distance between 5, 12: 1.678335779344151
# Custom distance between 5, 13: 1.6750253303874394
# Custom distance between 5, 14: 1.8032135514044259
# Custom distance between 5, 15: 1.7703544779986318
# Custom distance between 5, 16: 1.7972492292529632
# Custom distance between 5, 17: 1.703174668795431
# Custom distance between 5, 18: 1.7017314559735517
# Custom distance between 5, 19: 1.4931701329347946
# Custom distance between 6, 0: 1.3033506088807874
# Custom distance between 6, 1: 1.4573772590578717
# Custom distance between 6, 2: 1.0799026508530452
# Custom distance between 6, 3: 1.2012143808329954
# Custom distance between 6, 4: 0.8085392164992858
# Custom distance between 6, 5: 0.9619373563340452
# Custom distance between 6, 6: 0.663436602869702
# Custom distance between 6, 7: 0.9860717140133163
# Custom distance between 6, 8: 0.8700978103387902
# Custom distance between 6, 9: 1.25247532641697
# Custom distance between 6, 10: 1.1094379469602493
# Custom distance between 6, 11: 1.5004466763041229
# Custom distance between 6, 12: 1.330128889811148
# Custom distance between 6, 13: 1.6971856193206978
# Custom distance between 6, 14: 1.4853448119755575
# Custom distance between 6, 15: 1.8230532188417512
# Custom distance between 6, 16: 1.5208488612802007
# Custom distance between 6, 17: 1.8176062643678095
# Custom distance between 6, 18: 1.4754717561000592
# Custom distance between 6, 19: 1.6834173234146323
# Custom distance between 7, 0: 1.6852168394579485
# Custom distance between 7, 1: 1.4837972521429117
# Custom distance between 7, 2: 1.4879990034176744
# Custom distance between 7, 3: 1.1862545874461512
# Custom distance between 7, 4: 1.2125360639077634
# Custom distance between 7, 5: 0.853335203077026
# Custom distance between 7, 6: 0.9860717140133154
# Custom distance between 7, 7: 0.6329991150207638
# Custom distance between 7, 8: 0.9731288168448178
# Custom distance between 7, 9: 0.8557095533892565
# Custom distance between 7, 10: 1.2065920630554503
# Custom distance between 7, 11: 1.1797974743552462
# Custom distance between 7, 12: 1.4697678673843346
# Custom distance between 7, 13: 1.4739466944396782
# Custom distance between 7, 14: 1.6906377374537718
# Custom distance between 7, 15: 1.6988445676935013
# Custom distance between 7, 16: 1.795293085448991
# Custom distance between 7, 17: 1.7716472831639696
# Custom distance between 7, 18: 1.8157617466084282
# Custom distance between 7, 19: 1.6874629265809997
# Custom distance between 8, 0: 1.4856083052199738
# Custom distance between 8, 1: 1.6846344334051149
# Custom distance between 8, 2: 1.3465252197819844
# Custom distance between 8, 3: 1.4893063306180776
# Custom distance between 8, 4: 1.1008053166219673
# Custom distance between 8, 5: 1.2185771348158525
# Custom distance between 8, 6: 0.87009781033879
# Custom distance between 8, 7: 0.973128816844818
# Custom distance between 8, 8: 0.6994936562366905
# Custom distance between 8, 9: 0.9856576363310741
# Custom distance between 8, 10: 0.8440126394902648
# Custom distance between 8, 11: 1.2133676739736943
# Custom distance between 8, 12: 1.0972021201227824
# Custom distance between 8, 13: 1.47231805014124
# Custom distance between 8, 14: 1.3327990705802444
# Custom distance between 8, 15: 1.7008197294041607
# Custom distance between 8, 16: 1.4739631501647572
# Custom distance between 8, 17: 1.819921788671371
# Custom distance between 8, 18: 1.547082267760243
# Custom distance between 8, 19: 1.8065292171078156
# Custom distance between 9, 0: 1.8255221995312052
# Custom distance between 9, 1: 1.695660228084589
# Custom distance between 9, 2: 1.7222752168769961
# Custom distance between 9, 3: 1.4997877840106266
# Custom distance between 9, 4: 1.4973432094972323
# Custom distance between 9, 5: 1.1934072466027372
# Custom distance between 9, 6: 1.2524753264169701
# Custom distance between 9, 7: 0.8557095533892555
# Custom distance between 9, 8: 0.9856576363310736
# Custom distance between 9, 9: 0.6493411174190721
# Custom distance between 9, 10: 0.9822277010194108
# Custom distance between 9, 11: 0.8606218546058507
# Custom distance between 9, 12: 1.2292613450661245
# Custom distance between 9, 13: 1.1944924454350365
# Custom distance between 9, 14: 1.5079274265911886
# Custom distance between 9, 15: 1.5167614767353128
# Custom distance between 9, 16: 1.707709549427424
# Custom distance between 9, 17: 1.719933112680635
# Custom distance between 9, 18: 1.8416561826779123
# Custom distance between 9, 19: 1.7712792357993425
# Custom distance between 10, 0: 1.5401992168959755
# Custom distance between 10, 1: 1.7943323807907074
# Custom distance between 10, 2: 1.4974514107264938
# Custom distance between 10, 3: 1.6970237208967296
# Custom distance between 10, 4: 1.319724471272329
# Custom distance between 10, 5: 1.4746917852349153
# Custom distance between 10, 6: 1.109437946960249
# Custom distance between 10, 7: 1.2065920630554503
# Custom distance between 10, 8: 0.844012639490265
# Custom distance between 10, 9: 0.9822277010194106
# Custom distance between 10, 10: 0.6584680743055915
# Custom distance between 10, 11: 0.9647360135384836
# Custom distance between 10, 12: 0.8314958593437178
# Custom distance between 10, 13: 1.2045681759800348
# Custom distance between 10, 14: 1.1010100568011825
# Custom distance between 10, 15: 1.4889473293227855
# Custom distance between 10, 16: 1.32063957200892
# Custom distance between 10, 17: 1.7059996735688525
# Custom distance between 10, 18: 1.493758510014325
# Custom distance between 10, 19: 1.8042928331397876
# Custom distance between 11, 0: 1.8131218542000915
# Custom distance between 11, 1: 1.7496253610977233
# Custom distance between 11, 2: 1.8230327644861055
# Custom distance between 11, 3: 1.6936490612592356
# Custom distance between 11, 4: 1.6937488890363297
# Custom distance between 11, 5: 1.480910097813766
# Custom distance between 11, 6: 1.5004466763041235
# Custom distance between 11, 7: 1.1797974743552453
# Custom distance between 11, 8: 1.2133676739736956
# Custom distance between 11, 9: 0.8606218546058514
# Custom distance between 11, 10: 0.9647360135384832
# Custom distance between 11, 11: 0.6371809784888565
# Custom distance between 11, 12: 0.977481854477883
# Custom distance between 11, 13: 0.8539213000723914
# Custom distance between 11, 14: 1.2331964560756417
# Custom distance between 11, 15: 1.2070552977553914
# Custom distance between 11, 16: 1.4882673301562883
# Custom distance between 11, 17: 1.5078252255127058
# Custom distance between 11, 18: 1.713510377947968
# Custom distance between 11, 19: 1.6859036154264346
# Custom distance between 12, 0: 1.4683672838358577
# Custom distance between 12, 1: 1.7754866666388114
# Custom distance between 12, 2: 1.536262503223293
# Custom distance between 12, 3: 1.8028572266294522
# Custom distance between 12, 4: 1.4662130359782264
# Custom distance between 12, 5: 1.678335779344151
# Custom distance between 12, 6: 1.330128889811149
# Custom distance between 12, 7: 1.4697678673843348
# Custom distance between 12, 8: 1.0972021201227833
# Custom distance between 12, 9: 1.2292613450661256
# Custom distance between 12, 10: 0.8314958593437175
# Custom distance between 12, 11: 0.9774818544778835
# Custom distance between 12, 12: 0.6580413427926807
# Custom distance between 12, 13: 0.9586395231620365
# Custom distance between 12, 14: 0.8345905926815873
# Custom distance between 12, 15: 1.21209442700064
# Custom distance between 12, 16: 1.0794399850561924
# Custom distance between 12, 17: 1.4804474784622041
# Custom distance between 12, 18: 1.3200398250706602
# Custom distance between 12, 19: 1.6710826084810015
# Custom distance between 13, 0: 1.6886778623781356
# Custom distance between 13, 1: 1.66574080059879
# Custom distance between 13, 2: 1.8115800307304941
# Custom distance between 13, 3: 1.7593062463227143
# Custom distance between 13, 4: 1.8010357115798796
# Custom distance between 13, 5: 1.675025330387441
# Custom distance between 13, 6: 1.697185619320698
# Custom distance between 13, 7: 1.4739466944396789
# Custom distance between 13, 8: 1.472318050141241
# Custom distance between 13, 9: 1.1944924454350374
# Custom distance between 13, 10: 1.2045681759800364
# Custom distance between 13, 11: 0.8539213000723906
# Custom distance between 13, 12: 0.958639523162036
# Custom distance between 13, 13: 0.6326921385272968
# Custom distance between 13, 14: 0.9734608866219872
# Custom distance between 13, 15: 0.8632672364490025
# Custom distance between 13, 16: 1.2142294776394271
# Custom distance between 13, 17: 1.198573526963889
# Custom distance between 13, 18: 1.4901606741211353
# Custom distance between 13, 19: 1.4727086704682562
# Custom distance between 14, 0: 1.3220902829990366
# Custom distance between 14, 1: 1.6660320254974332
# Custom distance between 14, 2: 1.488004019273127
# Custom distance between 14, 3: 1.8142641671233475
# Custom distance between 14, 4: 1.529727284381537
# Custom distance between 14, 5: 1.803213551404425
# Custom distance between 14, 6: 1.4853448119755586
# Custom distance between 14, 7: 1.6906377374537715
# Custom distance between 14, 8: 1.3327990705802442
# Custom distance between 14, 9: 1.5079274265911906
# Custom distance between 14, 10: 1.1010100568011811
# Custom distance between 14, 11: 1.2331964560756419
# Custom distance between 14, 12: 0.8345905926815875
# Custom distance between 14, 13: 0.9734608866219867
# Custom distance between 14, 14: 0.6687524898258878
# Custom distance between 14, 15: 0.9721454219458934
# Custom distance between 14, 16: 0.833278256930647
# Custom distance between 14, 17: 1.2194926936602206
# Custom distance between 14, 18: 1.0952712527201283
# Custom distance between 14, 19: 1.4665590283225869
# Custom distance between 15, 0: 1.4926356643368979
# Custom distance between 15, 1: 1.4809714870824378
# Custom distance between 15, 2: 1.710424157489951
# Custom distance between 15, 3: 1.71404034271345
# Custom distance between 15, 4: 1.8213809999578983
# Custom distance between 15, 5: 1.7703544779986302
# Custom distance between 15, 6: 1.8230532188417514
# Custom distance between 15, 7: 1.6988445676935027
# Custom distance between 15, 8: 1.70081972940416
# Custom distance between 15, 9: 1.5167614767353135
# Custom distance between 15, 10: 1.4889473293227855
# Custom distance between 15, 11: 1.2070552977553919
# Custom distance between 15, 12: 1.2120944270006384
# Custom distance between 15, 13: 0.8632672364490024
# Custom distance between 15, 14: 0.9721454219458938
# Custom distance between 15, 15: 0.6527605620097618
# Custom distance between 15, 16: 0.9790849255478671
# Custom distance between 15, 17: 0.8730343021188334
# Custom distance between 15, 18: 1.2312828095140433
# Custom distance between 15, 19: 1.1868844969711838
# Custom distance between 16, 0: 1.0977545782365583
# Custom distance between 16, 1: 1.4573211515769726
# Custom distance between 16, 2: 1.3289759928368001
# Custom distance between 16, 3: 1.6990322350252318
# Custom distance between 16, 4: 1.469996726424721
# Custom distance between 16, 5: 1.7972492292529625
# Custom distance between 16, 6: 1.5208488612802
# Custom distance between 16, 7: 1.7952930854489904
# Custom distance between 16, 8: 1.4739631501647565
# Custom distance between 16, 9: 1.7077095494274241
# Custom distance between 16, 10: 1.320639572008921
# Custom distance between 16, 11: 1.488267330156289
# Custom distance between 16, 12: 1.0794399850561929
# Custom distance between 16, 13: 1.214229477639426
# Custom distance between 16, 14: 0.8332782569306467
# Custom distance between 16, 15: 0.979084925547868
# Custom distance between 16, 16: 0.6788611507355993
# Custom distance between 16, 17: 0.9879903339208713
# Custom distance between 16, 18: 0.8460034348593141
# Custom distance between 16, 19: 1.2108190000747714
# Custom distance between 17, 0: 1.2319199003834564
# Custom distance between 17, 1: 1.1819412770795368
# Custom distance between 17, 2: 1.4983037211454344
# Custom distance between 17, 3: 1.515996082369948
# Custom distance between 17, 4: 1.710732859280838
# Custom distance between 17, 5: 1.703174668795432
# Custom distance between 17, 6: 1.81760626436781
# Custom distance between 17, 7: 1.7716472831639705
# Custom distance between 17, 8: 1.8199217886713719
# Custom distance between 17, 9: 1.7199331126806343
# Custom distance between 17, 10: 1.7059996735688512
# Custom distance between 17, 11: 1.507825225512706
# Custom distance between 17, 12: 1.480447478462204
# Custom distance between 17, 13: 1.1985735269638895
# Custom distance between 17, 14: 1.2194926936602195
# Custom distance between 17, 15: 0.873034302118833
# Custom distance between 17, 16: 0.9879903339208709
# Custom distance between 17, 17: 0.662492583513965
# Custom distance between 17, 18: 0.9922324786431391
# Custom distance between 17, 19: 0.8561908679634141
# Custom distance between 18, 0: 0.845691937030838
# Custom distance between 18, 1: 1.1995785723793104
# Custom distance between 18, 2: 1.1031928819796095
# Custom distance between 18, 3: 1.5027786617208807
# Custom distance between 18, 4: 1.329391277196909
# Custom distance between 18, 5: 1.70173145597355
# Custom distance between 18, 6: 1.475471756100059
# Custom distance between 18, 7: 1.8157617466084257
# Custom distance between 18, 8: 1.5470822677602434
# Custom distance between 18, 9: 1.841656182677912
# Custom distance between 18, 10: 1.4937585100143242
# Custom distance between 18, 11: 1.7135103779479683
# Custom distance between 18, 12: 1.3200398250706606
# Custom distance between 18, 13: 1.4901606741211357
# Custom distance between 18, 14: 1.0952712527201274
# Custom distance between 18, 15: 1.2312828095140436
# Custom distance between 18, 16: 0.8460034348593133
# Custom distance between 18, 17: 0.9922324786431391
# Custom distance between 18, 18: 0.6756525088951884
# Custom distance between 18, 19: 0.9761802007124568
# Custom distance between 19, 0: 0.9807470362602051
# Custom distance between 19, 1: 0.8409952071527134
# Custom distance between 19, 2: 1.220513053740169
# Custom distance between 19, 3: 1.208815423012566
# Custom distance between 19, 4: 1.4915200577613865
# Custom distance between 19, 5: 1.4931701329347948
# Custom distance between 19, 6: 1.683417323414631
# Custom distance between 19, 7: 1.6874629265809993
# Custom distance between 19, 8: 1.8065292171078144
# Custom distance between 19, 9: 1.7712792357993428
# Custom distance between 19, 10: 1.8042928331397863
# Custom distance between 19, 11: 1.6859036154264333
# Custom distance between 19, 12: 1.6710826084810024
# Custom distance between 19, 13: 1.4727086704682557
# Custom distance between 19, 14: 1.4665590283225869
# Custom distance between 19, 15: 1.186884496971183
# Custom distance between 19, 16: 1.2108190000747725
# Custom distance between 19, 17: 0.8561908679634145
# Custom distance between 19, 18: 0.9761802007124567
# Custom distance between 19, 19: 0.6341104102300454
# Persistence intervals:
# [(0, (0.0, inf)), (0, (0.0, 0.9467362686872162)), (0, (0.0, 0.8645896060298768)), (0, (0.0, 0.8632672364490024)), (0, (0.0, 0.8606218546058514)), (0, (0.0, 0.8561908679634145)), (0, (0.0, 0.8557095533892555)), (0, (0.0, 0.8544652343329795)), (0, (0.0, 0.8539213000723906)), (0, (0.0, 0.853335203077026))]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
t2s = Traj2Sim()
list_traj = []

a=0.6
b=0.4

N=20
length=100
for i in range(2*N):
    if i%2 == 0:
        list_traj.append(great_circle_with_time(2*i*math.pi/(2*N), length, noise=1,time_i=int(0*length), time_f=int(a*length)))
    else:
        list_traj.append(great_circle_with_time(2*i*math.pi/(2*N), length, noise=1,time_i=int((1-a)*length), time_f=int(1*length)-1))    
        
plot_2pc_traj(list_traj)

t2s.set_trajectories(list_traj)
t2s.dist = 'custom'
t2s.compute_dist(verbose=False)
t2s.compute_sim(verbose=False)


print('Persistence intervals:')
pers = t2s.simplex_tree.persistence(homology_coeff_field=2, min_persistence=-0.1)
pers.sort(key=lambda x: x[1][0]-x[1][1])
print(pers[:10])

gudhi.plot_persistence_diagram(pers[:20])

# %%
t2s = Traj2Sim()
list_traj = []

a=0.4
b=0.3

N=25
length=100
for i in range(3*N):
    if i%3 == 0:
        list_traj.append(great_circle_with_time(2*i*math.pi/N, length, noise=1,time_i=int(0*length), time_f=int(a*length)))
    elif i%3 == 1:
        list_traj.append(great_circle_with_time(2*i*math.pi/N, length, noise=1,time_i=int((1-a)*length), time_f=int(1*length)-1))            
    else:
        list_traj.append(great_circle_with_time(2*i*math.pi/N, length, noise=1,time_i=int(b*length), time_f=int((1-b)*length)))

plot_3pc_traj(list_traj)

t2s.set_trajectories(list_traj)
t2s.dist = 'custom'
t2s.compute_dist(verbose=False)
t2s.compute_sim(verbose=False)


print('Persistence intervals:')
pers = t2s.simplex_tree.persistence(homology_coeff_field=2, min_persistence=-0.1)
pers.sort(key=lambda x: x[1][0]-x[1][1])
print(pers[:10])

gudhi.plot_persistence_diagram(pers[:20])
